# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Chargement du fichier avec parsing des dates
df = pd.read_csv(
    "../dags/data/final/historical_weather.csv", 
    parse_dates=["date_extraction", "date_observation"]
)

print(f"Lignes : {len(df)}")
print(f"Colonnes : {len(df.columns)}")
# Out:
# Lignes : 10065
# Colonnes : 21

# %%
# Aperçu des données
df.head()
# Out:
#        ville     date_extraction    date_observation  temperature_moy  \
# 0       Lyon 2025-07-04 15:22:58 2020-01-01 12:00:00             -0.1
# 1   Toulouse 2025-07-04 15:22:58 2020-01-01 12:00:00              8.2
# 2       Nice 2025-07-04 15:22:58 2020-01-01 12:00:00              8.8
# 3      Paris 2025-07-04 15:22:58 2020-01-01 12:00:00              2.2
# 4  Marseille 2025-07-04 15:22:58 2020-01-01 12:00:00              4.8
#
#    temp_min  temp_max  humidite_moy  precipitation  vent_moyen  \
# 0      -0.7       0.5            99          0.000         6.9
# 1       4.9      11.2            80          0.000         7.9
# 2       5.8      14.0            65          0.000        23.6
# 3      -0.7       4.5            98          0.028        10.8
# 4       0.7      10.7            88          0.039         8.7
#
#    visibilite_moy  ... annee  mois  jour  saison temp_ideale  peu_vent  \
# 0             0.2  ...  2020     1     1   Hiver       False      True
# 1            19.5  ...  2020     1     1   Hiver       False      True
# 2            25.6  ...  2020     1     1   Hiver       False     False
# 3             1.8  ...  2020     1     1   Hiver       False      True
# 4             9.0  ...  2020     1     1   Hiver       False      True
#
#    peu_pluie  bonne_visibilite  score_meteo  periode_recommandee
# 0       True             False           50                False
# 1       True              True           70                False
# 2       True              True           50                False
# 3       True             False           50                False
# 4       True              True           70                False
#
# [5 rows x 21 columns]
