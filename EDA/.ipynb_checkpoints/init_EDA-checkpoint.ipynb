# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Loading raw data
df = pd.read_csv("../dags/data/historical/historical.csv", parse_dates=["datetime"])
print(f"Data period: {df['datetime'].min()} to {df['datetime'].max()}")
print(f"Dimensions : {df.shape}\nCities : {df['name'].unique().tolist()}")
# Out:
# Data period: 2020-01-01 00:00:00 to 2025-06-29 00:00:00
# Dimensions : (10035, 33)
# Cities : ['Lyon', 'Paris', 'Toulouse', 'Marseille', 'Nice']

# %%
# Columns
print("Dataset columns")
print(df.columns.tolist())
# Out:
# Dataset columns
# ['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax', 'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise', 'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations']

# %%
# Data overview
df.head()
# Out:
#    name   datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Lyon 2020-01-01      0.5     -0.7  -0.1           0.5          -2.2
# 1  Lyon 2020-01-02      3.2     -0.8   0.5           3.2          -4.4
# 2  Lyon 2020-01-03      9.8      1.7   5.1           9.8          -0.6
# 3  Lyon 2020-01-04      8.8      4.0   6.5           6.4           0.5
# 4  Lyon 2020-01-05      6.9     -0.3   3.2           4.6          -2.2
#
#    feelslike  dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       -0.8 -0.2      99.0  ...          3.0      2.0         NaN
# 1       -0.7  0.0      96.6  ...          1.7      1.0         NaN
# 2        4.2  3.7      91.3  ...          2.6      1.0         NaN
# 3        4.5  4.1      85.9  ...          2.1      1.0         NaN
# 4        1.4  0.6      83.5  ...          3.5      3.0         NaN
#
#                sunrise               sunset  moonphase  \
# 0  2020-01-01T08:21:49  2020-01-01T17:06:21       0.20
# 1  2020-01-02T08:21:51  2020-01-02T17:07:16       0.23
# 2  2020-01-03T08:21:51  2020-01-03T17:08:13       0.25
# 3  2020-01-04T08:21:47  2020-01-04T17:09:13       0.30
# 4  2020-01-05T08:21:41  2020-01-05T17:10:14       0.33
#
#                conditions                                        description  \
# 0        Partially cloudy                  Partly cloudy throughout the day.
# 1        Partially cloudy                  Partly cloudy throughout the day.
# 2          Rain, Overcast  Cloudy skies throughout the day with late afte...
# 3  Rain, Partially cloudy  Partly cloudy throughout the day with morning ...
# 4        Partially cloudy                  Partly cloudy throughout the day.
#
#                 icon                                         stations
# 0                fog        07481099999,D2904,07480099999,07482099999
# 1  partly-cloudy-day        07481099999,D2904,07480099999,07482099999
# 2               rain        07481099999,D2904,07480099999,07482099999
# 3               rain  07481099999,E8103,D2904,07480099999,07482099999
# 4  partly-cloudy-day        07481099999,D2904,07480099999,07482099999
#
# [5 rows x 33 columns]

# %%
# Data distribution by city
df["name"].value_counts().plot(kind="bar", color="green")
plt.title("Number of observations per city");
plt.ylabel("number of data")
# Out:
# Text(0, 0.5, 'number of data')

# %%
# Missing values
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing values by columns");

# %%
# Temperature by city (average temperature)
plt.figure(figsize=(14, 8))
for ville in df["name"].unique():
    df_ville = df[df["name"] == ville].sort_values("datetime")
    plt.plot(df_ville["datetime"], df_ville["temp"], label=ville, alpha=0.7)
plt.xlabel("date")
plt.ylabel("temperature (°C)")
plt.title("Temperature trends by city")
plt.legend()
plt.grid(True);

# %%
# All weather conditions
all_conditions = df["conditions"].value_counts()

fig, ax = plt.subplots(figsize=(15, 10))
wedges, texts = ax.pie(all_conditions.values, startangle=90)

percentages = (all_conditions.values / all_conditions.sum()) * 100
legend_labels = [f"{condition} - {percent:.1f}%" for condition, percent in zip(all_conditions.index, percentages)]

ax.legend(wedges, legend_labels, title="Weather conditions", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.title("Distribution of all weather conditions")
plt.tight_layout()
